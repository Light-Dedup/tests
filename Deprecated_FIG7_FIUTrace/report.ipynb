# %%
import pandas as pd
with open("./performance-comparison-table", "r") as f:
    df = pd.read_csv(f, delim_whitespace=True, engine='python')
df.head()
# Out:
#    file_system                              trace  cblks  job  \
# 0  Light-Dedup  homes-110108-112108.1-21.blkparse      1    1
# 1  Light-Dedup  homes-110108-112108.1-21.blkparse      1    2
# 2  Light-Dedup  homes-110108-112108.1-21.blkparse      1    4
# 3  Light-Dedup  homes-110108-112108.1-21.blkparse      1    8
# 4  Light-Dedup  homes-110108-112108.1-21.blkparse      1   16
#
#    bandwidth(MiB/s)
# 0           629.892
# 1          1061.546
# 2          1605.494
# 3          1702.688
# 4          1362.948

# %% [markdown]
# # The throughput of Light-Dedup compared to NOVA (under three traces) when the threads number is greater than 8

# %%
newdf = df[df['file_system'] == "Light-Dedup"][df["job"] == 1].reset_index()
newdf["Light-Dedup/NOVA"] = (df[df['file_system'] == "Light-Dedup"][df["job"] == 1]["bandwidth(MiB/s)"].reset_index() / df[df['file_system'] == "NOVA"][df["job"] == 1]["bandwidth(MiB/s)"].reset_index())["bandwidth(MiB/s)"]
newdf
# Out:
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     index  file_system                                              trace  \
# 0       3  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 1       4  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 2       8  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 3       9  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 4      13  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
# 5      14  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
# 6      63  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 7      64  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 8      68  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 9      69  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 10     73  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
# 11     74  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
#
#     cblks  job  bandwidth(MiB/s)  Light-Dedup/NOVA
# 0       1    8          1702.688          1.021546
# 1       1   16          1362.948          0.946492
# 2       1    8          2318.000          1.103205
# 3       1   16          2070.264          1.129148
# 4       1    8          3575.440          1.984702
# 5       1   16          3524.988          2.273461
# 6     512    8          1904.322          1.124111
# 7     512   16          1487.648          1.215311
# 8     512    8          2978.546          1.418582
# 9     512   16          2509.164          1.580205
# 10    512    8          4385.196          2.431379
# 11    512   16          4229.348          2.997488

# %% [markdown]
# # How about single thread?

# %%
newdf = df[df['file_system'] == "Light-Dedup"][df["job"] >= 1].reset_index()
newdf["Light-Dedup/NOVA"] = (df[df['file_system'] == "Light-Dedup"][df["job"] >= 8]["bandwidth(MiB/s)"].reset_index() / df[df['file_system'] == "NOVA"][df["job"] >= 8]["bandwidth(MiB/s)"].reset_index())["bandwidth(MiB/s)"]
newdf
# Out:
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     index  file_system                                              trace  \
# 0       3  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 1       4  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 2       8  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 3       9  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 4      13  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
# 5      14  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
# 6      63  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 7      64  Light-Dedup                  homes-110108-112108.1-21.blkparse
# 8      68  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 9      69  Light-Dedup  webmail+online.cs.fiu.edu-110108-113008.1-21.b...
# 10     73  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
# 11     74  Light-Dedup      cheetah.cs.fiu.edu-110108-113008.1-2.blkparse
#
#     cblks  job  bandwidth(MiB/s)  Light-Dedup/NOVA
# 0       1    8          1702.688          1.021546
# 1       1   16          1362.948          0.946492
# 2       1    8          2318.000          1.103205
# 3       1   16          2070.264          1.129148
# 4       1    8          3575.440          1.984702
# 5       1   16          3524.988          2.273461
# 6     512    8          1904.322          1.124111
# 7     512   16          1487.648          1.215311
# 8     512    8          2978.546          1.418582
# 9     512   16          2509.164          1.580205
# 10    512    8          4385.196          2.431379
# 11    512   16          4229.348          2.997488
